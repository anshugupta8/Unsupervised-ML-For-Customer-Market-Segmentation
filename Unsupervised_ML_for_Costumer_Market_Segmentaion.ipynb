# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
#from jupyterthemes import jtplot
#jtplot.style(theme="monokai",context="notebook",ticks=True,grid=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-5887faa5-c7bf-4027-aa2b-277db6330a87" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5887faa5-c7bf-4027-aa2b-277db6330a87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CC GENERAL.csv to CC GENERAL.csv

# %%
import io
creditcard_df=pd.read_csv(io.BytesIO(upload['CC GENERAL.csv']))

# %%
creditcard_df
# Out:
#      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0     C10001    40.900749  ...          0.000000      12
# 1     C10002  3202.467416  ...          0.222222      12
# 2     C10003  2495.148862  ...          0.000000      12
# 3     C10004  1666.670542  ...          0.000000      12
# 4     C10005   817.714335  ...          0.000000      12
# ...      ...          ...  ...               ...     ...
# 8945  C19186    28.493517  ...          0.500000       6
# 8946  C19187    19.183215  ...          0.000000       6
# 8947  C19188    23.398673  ...          0.250000       6
# 8948  C19189    13.457564  ...          0.250000       6
# 8949  C19190   372.708075  ...          0.000000       6
#
# [8950 rows x 18 columns]

# %%
creditcard_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
print("Maximum balance",creditcard_df['BALANCE'].max())
print("Minimum balance",creditcard_df['BALANCE'].min())
print("average balance",creditcard_df['BALANCE'].mean())
# Out:
# Maximum balance 19043.13856
# Minimum balance 0.0
# average balance 1564.4748276781038

# %%
creditcard_df[creditcard_df['ONEOFF_PURCHASES']== creditcard_df['ONEOFF_PURCHASES'].max()]
# Out:
#     CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 550  C10574  11547.52001  ...              0.25      12
#
# [1 rows x 18 columns]

# %%
sns.heatmap(creditcard_df.isnull(),cmap="Greens")

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
creditcard_df.loc[(creditcard_df['MINIMUM_PAYMENTS'].isnull()==True) ,'MINIMUM_PAYMENTS']=creditcard_df['MINIMUM_PAYMENTS'].mean()

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
creditcard_df.loc[(creditcard_df['CREDIT_LIMIT'].isnull()==True),'CREDIT_LIMIT']=creditcard_df['CREDIT_LIMIT'].mean()

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
sns.heatmap(creditcard_df.isnull(),cmap="Greens")

# %%
creditcard_df.duplicated().sum()
# Out:
# 0

# %%
creditcard_df.drop(['CUST_ID'],axis=1,inplace=True)

# %%
creditcard_df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
plt.figure(figsize=(10,50))
for i in range(len(creditcard_df.columns)):
  plt.subplot(17,1,i+1)
  sns.distplot(creditcard_df[creditcard_df.columns[i]],kde_kws={'color':'b','lw':3,'label':'KDE'},hist_kws={'color':'g'})
  plt.title(creditcard_df.columns[i])

plt.tight_layout()

# %%
correlation=creditcard_df.corr()
plt.figure(figsize=(30,30))
sns.heatmap(correlation,annot=True)

# %%
ss=StandardScaler()
creditcard_df_scaled=ss.fit_transform(creditcard_df)

# %%
creditcard_df_scaled.shape
# Out:
# (8950, 17)

# %%
creditcard_df_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
#Finding the no. of cluster
#using elbow method

score_1=[]

for i in range(1,20):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(creditcard_df_scaled)
  score_1.append(kmeans.inertia_)

plt.plot(score_1,'bx-')

#for wcss (within cluster square of sums ) calculation we use 'inertia_' attribute

# %%
creditcard_7attri=creditcard_df_scaled[:,:7]

# %%
creditcard_7attri.shape
# Out:
# (8950, 7)

# %%
score_1=[]

for i in range(1,20):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(creditcard_7attri)
  score_1.append(kmeans.inertia_)

plt.plot(score_1,'bx-')

# %%
#Applying Kmeans to the dataframe

kmeans=KMeans(4)
kmeans.fit(creditcard_df_scaled)
labels=kmeans.labels_

# %%
kmeans.cluster_centers_.shape
# Out:
# (4, 17)

# %%
kmeans.cluster_centers_
# Out:
# array([[-2.65509413e-01, -3.68721257e-01, -3.43110023e-01,
#         -2.30452980e-01, -3.87695614e-01, -1.82432849e-01,
#         -7.97563742e-01, -3.89369186e-01, -7.14033122e-01,
#         -1.01225848e-01, -1.64538216e-01, -4.74824623e-01,
#         -3.34539970e-01, -2.61775188e-01, -1.19266423e-01,
#         -2.58861118e-01, -5.28678153e-02],
#        [ 1.45957775e+00,  3.84753065e-01, -2.34638427e-01,
#         -1.63914013e-01, -2.53746975e-01,  1.68897201e+00,
#         -5.04847568e-01, -2.12939102e-01, -4.50201244e-01,
#          1.74594805e+00,  1.61714316e+00, -2.83579688e-01,
#          8.38967661e-01,  6.03820830e-01,  4.90909814e-01,
#         -4.06367280e-01, -9.71460234e-02],
#        [ 9.54484507e-01,  4.62693629e-01,  3.12584465e+00,
#          2.71325131e+00,  2.40646962e+00, -1.55090594e-01,
#          1.13633760e+00,  1.79865349e+00,  1.06591778e+00,
#         -3.19095705e-01, -1.70458235e-01,  3.00325068e+00,
# ...

# %%
cluster_center=pd.DataFrame(data=kmeans.cluster_centers_ , columns=creditcard_df.columns)

# %%
cluster_center
# Out:
#     BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT    TENURE
# 0 -0.265509          -0.368721  ...         -0.258861 -0.052868
# 1  1.459578           0.384753  ...         -0.406367 -0.097146
# 2  0.954485           0.462694  ...          0.454703  0.324140
# 3 -0.321755           0.242492  ...          0.395230  0.057654
#
# [4 rows x 17 columns]

# %%
cluster_center=ss.inverse_transform(cluster_center)
cluster_center=pd.DataFrame(data=cluster_center,columns=creditcard_df.columns)
cluster_center
# Out:
#        BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT     TENURE
# 0  1011.839396           0.789924  ...          0.078002  11.446568
# 1  4602.462714           0.968415  ...          0.034859  11.387312
# 2  3551.153761           0.986879  ...          0.286707  11.951100
# 3   894.768927           0.934715  ...          0.269313  11.594474
#
# [4 rows x 17 columns]

# %%
labels.min()
# Out:
# 0

# %%
labels.max()
# Out:
# 3

# %%
y_kmeans=kmeans.fit_predict(creditcard_df_scaled)
y_kmeans
# Out:
# array([3, 0, 1, ..., 1, 3, 3], dtype=int32)

# %%
creditcard_df_cluster=pd.concat([creditcard_df,pd.DataFrame({'cluster':labels})],axis=1)
creditcard_df_cluster
# Out:
#           BALANCE  BALANCE_FREQUENCY  ...  TENURE  cluster
# 0       40.900749           0.818182  ...      12        0
# 1     3202.467416           0.909091  ...      12        1
# 2     2495.148862           1.000000  ...      12        3
# 3     1666.670542           0.636364  ...      12        0
# 4      817.714335           1.000000  ...      12        0
# ...           ...                ...  ...     ...      ...
# 8945    28.493517           1.000000  ...       6        3
# 8946    19.183215           1.000000  ...       6        3
# 8947    23.398673           0.833333  ...       6        3
# 8948    13.457564           0.833333  ...       6        0
# 8949   372.708075           0.666667  ...       6        0
#
# [8950 rows x 18 columns]

# %%
for i in creditcard_df.columns:
  plt.figure(figsize=(35,5))
  for j in range(4):
    plt.subplot(1,4,j+1)
    cluster=creditcard_df_cluster[creditcard_df_cluster['cluster']==j]
    cluster[i].hist(bins=20)
    plt.title("{} \ncluster {}".format(i,j))


  plt.show()

# %%
#applying Principal Component Analysis(PCA)

pca=PCA(n_components=2)
principal_comp=pca.fit_transform(creditcard_df_scaled)
principal_comp
# Out:
# array([[-1.68222528, -1.07647321],
#        [-1.13830858,  2.50641061],
#        [ 0.96968512, -0.38350848],
#        ...,
#        [-0.92619936, -1.81076323],
#        [-2.33655419, -0.65798073],
#        [-0.55641667, -0.40044512]])

# %%
pca_df=pd.DataFrame(data=principal_comp,columns=['pca_1','pca_2'])

pca_df=pd.concat([pca_df,pd.DataFrame({'cluster':labels})],axis=1)

# %%
pca_df
# Out:
#          pca_1     pca_2  cluster
# 0    -1.682225 -1.076473        0
# 1    -1.138309  2.506411        1
# 2     0.969685 -0.383508        3
# 3    -0.873637  0.043121        0
# 4    -1.599436 -0.688590        0
# ...        ...       ...      ...
# 8945 -0.359623 -2.016113        3
# 8946 -0.564369 -1.639120        3
# 8947 -0.926199 -1.810763        3
# 8948 -2.336554 -0.657981        0
# 8949 -0.556417 -0.400445        0
#
# [8950 rows x 3 columns]

# %%
#plot the cluster

plt.figure(figsize=(10,10))
sns.scatterplot(x='pca_1',y='pca_2',hue='cluster',data=pca_df,palette=['green','red','yellow','gray'])
plt.show()
